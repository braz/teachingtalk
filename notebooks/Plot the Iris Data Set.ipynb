# %% [markdown]
# # An example of how to plot Fisher's Iris Data
#
# This python notebook highlights a good example of the typical minor cleanups required for data analytics.
#
#  * Load the data (in this case from the Sci-kit learn/sklearn datasets)
#  * It converts the data into a Pandas Dataframe and renames the columns to the names of the features
#  * We then add a 'target' column to the Dataframe which will represent one of the three Iris species (0,1,2)
#  * We then plot the petal width against the petal length
#    * The colors list is used to associate back to one of the Iris species to help distinguish them in the plot

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
# Load the Iris data from sci-kit learn
from sklearn import datasets
data = datasets.load_iris()
 
# create a Pandas DataFrame
df = pd.DataFrame(data.data, columns=data.feature_names)
# Add a target (0,1,2) to the data frame to link to the iris species
df['target'] = pd.DataFrame(data.target)
df.head()

plt.clf()
plt.figure(figsize = (10, 6))
# Create an array to hold the three species names
names = data.target_names
colors = ['b','r','g']
# Create an array mapping the target to species name in 'names'
label = (data.target).astype(np.int)
plt.title('Petal Width vs Petal Length')
plt.xlabel(data.feature_names[2])
plt.ylabel(data.feature_names[3])
# Plot each species in turn
for i in range(len(names)):
	# Extract the details for the current species
    bucket = df[df['target'] == i]
    # Limit the details to just petal width and petal length
    bucket = bucket.iloc[:,[2,3]].values
    # Plot Petal Width vs Petal Length for the current species
    plt.scatter(bucket[:, 0], bucket[:, 1], label=names[i]) 
# Add the legend to the diagram
plt.legend()
# Show the rendered image
plt.show()
